# %% [markdown]
# # Tarea 2: Construcción de cuadernos

# %% [markdown]
# ## Logo
#
# ![PythonLogo](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP._OXvLGudBPLnflX8ZMimMAHaEH%26pid%3DApi&f=1&ipt=1081015b5efdcf418bebc895245cc37ad655e0f26d89d21ab6e9e4129942110b&ipo=images)

# %% [markdown]
# ## Autor
#
# **Por Alfredo Morales Roa**
#
# ![AMR1.JPG](attachment:8f42932e-8065-4835-ad27-5a07e14e5d62.JPG)
#
# *Licenciado en Filología Alemana por la Universidad Nacional de Colombia y Magíster en Lingüística con énfasis en investigación por el Instituto Caro y Cuervo. Sus áreas de interés son la lexicografía y la lingüística computacional y de corpus. También trabaja en la implementacón de técnicas y métricas en el área de la bibliometría. Además, ha sido director de una editorial universitaria.*

# %% [markdown]
# ## Concepto de ciencia de datos
#
# Según Kelleheer & Tierney (2018), la ciencia de datos es la aplicación de un conjunto de principios, definiciones de problemas, algoritmos y procesos de extracción de patrones no obvios y útiles de grandes conjuntos de datos.

# %% [markdown]
# ## Un concepto en estadística (Wolfe & Schneider, 2017)
#
# The **mean** of the observations in a data collection is their numerical average. That is, the sume of the data values divided by the number of observations in the data collection. So, if x<sub>1</sub>, x<sub>2</sub>,..., x<sub>n</sub> are the *n* observations in our data collection, their mean is
#
# ![MeanEquation.png](attachment:198e88f1-c3fd-4068-bb94-d028a2bc235d.png)

# %% [markdown]
# ## Bibliografía
#
# Kelleher, J. and Tierney, B. (2018) *Data Science*. MIT Press https://mitpress.mit.edu/9780262535434/data-science/
#
# Wolfe, D. and Schneider, G. (2017) *Intuitive Introductory Statistics*. Springer https://link.springer.com/book/10.1007/978-3-319-56072-4#bibliographic-information
